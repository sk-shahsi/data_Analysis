# %%
import pandas as pd
path = "D:/Data_Analysis/dataclining.xlsx"
df= pd.read_excel(path)
print(df)
# Out:
#     s.no     A   B     C     D     E  length
# 0      1   2.0   1   5.0   3.0   4.0    45.0
# 1      2   4.0   3  10.0   6.0   8.0    43.0
# 2      3   6.0   5  15.0   9.0  12.0    66.0
# 3      4   8.0   7  20.0  12.0  16.0    78.0
# 4      5  10.0   9  25.0  15.0  20.0    32.0
# 5      6  12.0  11  30.0  18.0  24.0    12.0
# 6      7  14.0  13  35.0  21.0  28.0    54.0
# 7      8  16.0  15  40.0  24.0  32.0    67.0
# 8      9  18.0  17  45.0  27.0  36.0    77.0
# 9     10  20.0  19  50.0  30.0  40.0    89.0
# 10    11   NaN  21   NaN   NaN   NaN     NaN
# 11    12   NaN  22   NaN   NaN  45.0     NaN

# %%
import numpy as np
bins = np.linspace(min(df["length"]),max(df["length"]),4)

# %%
group_name = ["Low","Medium","High"]

# %%
df["length_bin"] = pd.cut(df["length"],bins,labels=group_name,include_lowest=True)

# %%
df.head(5)
# Out:
#    s.no     A  B     C     D     E  length length_bin
# 0     1   2.0  1   5.0   3.0   4.0    45.0     Medium
# 1     2   4.0  3  10.0   6.0   8.0    43.0     Medium
# 2     3   6.0  5  15.0   9.0  12.0    66.0       High
# 3     4   8.0  7  20.0  12.0  16.0    78.0       High
# 4     5  10.0  9  25.0  15.0  20.0    32.0        Low

# %%
.#Categorical To Numeric
pd.get_dummies(df["length"])
# Out:
#      12.0   32.0   43.0   45.0   54.0   66.0   67.0   77.0   78.0   89.0
# 0   False  False  False   True  False  False  False  False  False  False
# 1   False  False   True  False  False  False  False  False  False  False
# 2   False  False  False  False  False   True  False  False  False  False
# 3   False  False  False  False  False  False  False  False   True  False
# 4   False   True  False  False  False  False  False  False  False  False
# 5    True  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False   True  False  False  False  False  False
# 7   False  False  False  False  False  False   True  False  False  False
# 8   False  False  False  False  False  False  False   True  False  False
# 9   False  False  False  False  False  False  False  False  False   True
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False

# %%
df.describe()
# Out:
#             s.no          A          B          C          D          E  \
# count  12.000000  10.000000  12.000000  10.000000  10.000000  11.000000
# mean    6.500000  11.000000  11.916667  27.500000  16.500000  24.090909
# std     3.605551   6.055301   7.076958  15.138252   9.082951  13.419795
# min     1.000000   2.000000   1.000000   5.000000   3.000000   4.000000
# 25%     3.750000   6.500000   6.500000  16.250000   9.750000  14.000000
# 50%     6.500000  11.000000  12.000000  27.500000  16.500000  24.000000
# 75%     9.250000  15.500000  17.500000  38.750000  23.250000  34.000000
# max    12.000000  20.000000  22.000000  50.000000  30.000000  45.000000
#
#           length
# count  10.000000
# mean   56.300000
# std    23.664554
# min    12.000000
# 25%    43.500000
# 50%    60.000000
# 75%    74.500000
# max    89.000000

# %%
df.head(5)
# Out:
#    s.no     A  B     C     D     E  length length_bin
# 0     1   2.0  1   5.0   3.0   4.0    45.0     Medium
# 1     2   4.0  3  10.0   6.0   8.0    43.0     Medium
# 2     3   6.0  5  15.0   9.0  12.0    66.0       High
# 3     4   8.0  7  20.0  12.0  16.0    78.0       High
# 4     5  10.0  9  25.0  15.0  20.0    32.0        Low

# %%
index = pd.Index(df["length"])

# %%
index.value_counts()
# Out:
# length
# 45.0    1
# 43.0    1
# 66.0    1
# 78.0    1
# 32.0    1
# 12.0    1
# 54.0    1
# 67.0    1
# 77.0    1
# 89.0    1
# Name: count, dtype: int64

# %%
#ploting Graph 1,box Graph
import seaborn as sns
sns.boxplot(x="length",y="E",data=df)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='length', ylabel='E'>

# %%
#scaterPlot
import matplotlib.pyplot as plt
x= df["length"]
y = df["E"]

plt.scatter(x,y)
plt.title("Scatterplot along the x and y axis")
plt.xlabel("Length")
plt.ylabel("width")
# Out:
# Text(0, 0.5, 'width')

# %%
#Gruping
import numpy as np
grp = df.groupby("A")
grp.aggregate(np.sum)
# Out:
# C:\Users\eraas\AppData\Local\Temp\ipykernel_11240\1753994336.py:4: FutureWarning: The provided callable <function sum at 0x00000180FE1EF2E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp.aggregate(np.sum)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 import numpy as np
#       3 grp = df.groupby("A")
# ----> 4 grp.aggregate(np.sum)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
# ...

# %%
grp = df.groupby(["A","B"])
grp. aggregate(np.sum)
# Out:
# C:\Users\eraas\AppData\Local\Temp\ipykernel_11240\1288524141.py:2: FutureWarning: The provided callable <function sum at 0x00000180FE1EF2E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp. aggregate(np.sum)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 grp = df.groupby(["A","B"])
# ----> 2 grp. aggregate(np.sum)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
# ...

# %%
#pivot
df_20 = pd.DataFrame({'S.No':[1,2,3,4,5],'A':['Apple','ant','ankel','Air','Arm'],'B':['ball','Bat','bare','ballon','boy',],'C':['Cat','cake','car','cow','coat'],'D':['Dog','duck','doll','deer','drum']})
print(df_20)
# Out:
#    S.No      A       B     C     D
# 0     1  Apple    ball   Cat   Dog
# 1     2    ant     Bat  cake  duck
# 2     3  ankel    bare   car  doll
# 3     4    Air  ballon   cow  deer
# 4     5    Arm     boy  coat  drum

# %%
df_20.pivot(index = 'A',columns = 'B', values='C')
# Out:
# B       Bat ball ballon bare   boy
# A
# Air     NaN  NaN    cow  NaN   NaN
# Apple   NaN  Cat    NaN  NaN   NaN
# Arm     NaN  NaN    NaN  NaN  coat
# ankel   NaN  NaN    NaN  car   NaN
# ant    cake  NaN    NaN  NaN   NaN

# %%
df_20.pivot(index = "S.No", columns ='A')['B']
# Out:
# A        Air Apple  Arm ankel  ant
# S.No
# 1        NaN  ball  NaN   NaN  NaN
# 2        NaN   NaN  NaN   NaN  Bat
# 3        NaN   NaN  NaN  bare  NaN
# 4     ballon   NaN  NaN   NaN  NaN
# 5        NaN   NaN  boy   NaN  NaN

# %%
df_20.pivot(index = 's.No',columns = 'A', values=['B','C'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 's.No'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ...

# %%
#Heat Map
import numpy as np
np.random.seed(0)
import seaborn as sns

uniform = np.random.rand(5,6)
print(uniform)
# Out:
# [[0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276 0.38344152 0.79172504 0.52889492]
#  [0.56804456 0.92559664 0.07103606 0.0871293  0.0202184  0.83261985]
#  [0.77815675 0.87001215 0.97861834 0.79915856 0.46147936 0.78052918]
#  [0.11827443 0.63992102 0.14335329 0.94466892 0.52184832 0.41466194]]

# %%
print(uniform)
# Out:
# [[0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276 0.38344152 0.79172504 0.52889492]
#  [0.56804456 0.92559664 0.07103606 0.0871293  0.0202184  0.83261985]
#  [0.77815675 0.87001215 0.97861834 0.79915856 0.46147936 0.78052918]
#  [0.11827443 0.63992102 0.14335329 0.94466892 0.52184832 0.41466194]]

# %%
heat_map = sns.heatmap(uniform)

# %%
heat_map_2= sns.heatmap(uniform,vmin =0,vmax = 1)

# %%
normal_data = np.random.randn(6,6)
print(normal_data)
# Out:
# [[ 0.8644362  -0.74216502  2.26975462 -1.45436567  0.04575852 -0.18718385]
#  [ 1.53277921  1.46935877  0.15494743  0.37816252 -0.88778575 -1.98079647]
#  [-0.34791215  0.15634897  1.23029068  1.20237985 -0.38732682 -0.30230275]
#  [-1.04855297 -1.42001794 -1.70627019  1.9507754  -0.50965218 -0.4380743 ]
#  [-1.25279536  0.77749036 -1.61389785 -0.21274028 -0.89546656  0.3869025 ]
#  [-0.51080514 -1.18063218 -0.02818223  0.42833187  0.06651722  0.3024719 ]]

# %%
heat_map_3 = sns.heatmap(normal_data,center =0)

# %%
flights = sns.load_dataset("flights")
flights =flights.pivot(index="month", columns="year", values="passengers")
heat_map_4=sns.heatmap(flights)

# %%
heat_map_5= sns.heatmap(flights,annot=True,fmt="d")

# %%
heat_map_5= sns.heatmap(flights,annot=True,fmt="1f")

# %%
heat_map_6 = sns.heatmap(flights,cmap='YlGnBu')

# %%
heat_map_7 = sns.heatmap(flights,camp='RdBu')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 heat_map_7 = sns.heatmap(flights,camp='RdBu')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:306, in _HeatMapper.plot(self, ax, cax, kws)
#     303     kws.setdefault("vmax", self.vmax)
#     305 # Draw the heatmap
# --> 306 mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     308 # Set the axis limits
# ...

# %%
heat_map_8 = sns.heatmap(flights,bar="False")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 heat_map_8 = sns.heatmap(flights,bar="False")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\matrix.py:306, in _HeatMapper.plot(self, ax, cax, kws)
#     303     kws.setdefault("vmax", self.vmax)
#     305 # Draw the heatmap
# --> 306 mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     308 # Set the axis limits
# ...

# %%
flights = sns.load_dataset("flights")
sns.regplot(x="passengers",y="year",data=flights)
# Out:
# <Axes: xlabel='passengers', ylabel='year'>

# %%
from scipy import stats
flights = sns.load_dataset("flights")
print(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
pasenger_correlation = stats.pearsonr(flights['year'],flights['passengers'])
print(pasenger_correlation)
# Out:
# PearsonRResult(statistic=np.float64(0.92182383529242), pvalue=np.float64(2.581042551911042e-60))

# %%
#simple linear Regration
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
x = flights[['year']]
y = flights[['passengers']]

# %%
lm.fit(x,y)
LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 lm.fit(x,y)
#       2 LinearRegression()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:618, in LinearRegression.fit(self, X, y, sample_weight)
#     614 n_jobs_ = self.n_jobs
#     616 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 618 X, y = validate_data(
#     619     self,
# ...

# %%
#Multiple Linear Regretion

from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
print(df)
# Out:
#     s.no     A   B     C     D     E  length length_bin
# 0      1   2.0   1   5.0   3.0   4.0    45.0     Medium
# 1      2   4.0   3  10.0   6.0   8.0    43.0     Medium
# 2      3   6.0   5  15.0   9.0  12.0    66.0       High
# 3      4   8.0   7  20.0  12.0  16.0    78.0       High
# 4      5  10.0   9  25.0  15.0  20.0    32.0        Low
# 5      6  12.0  11  30.0  18.0  24.0    12.0        Low
# 6      7  14.0  13  35.0  21.0  28.0    54.0     Medium
# 7      8  16.0  15  40.0  24.0  32.0    67.0       High
# 8      9  18.0  17  45.0  27.0  36.0    77.0       High
# 9     10  20.0  19  50.0  30.0  40.0    89.0       High
# 10    11   NaN  21   NaN   NaN   NaN     NaN        NaN
# 11    12   NaN  22   NaN   NaN  45.0     NaN        NaN

# %%
x = df[['A','B','C']]
y = df[['D']]

# %%
lm.fit(x,y)
LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 lm.fit(x,y)
#       2 LinearRegression()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:618, in LinearRegression.fit(self, X, y, sample_weight)
#     614 n_jobs_ = self.n_jobs
#     616 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 618 X, y = validate_data(
#     619     self,
# ...

# %%
yhat = lm.predict(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 yhat = lm.predict(x)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
#     275     check_is_fitted(self)
# --> 277     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     278     coef_ = self.coef_
#     279     if coef_.ndim == 1:
#
# ...

# %%
print(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x='year',y='passengers',data=flights)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
#Resdual Plot
#Resdual value

# %%
import seaborn as sns
sns.residplot(x="year", y="passengers", data=flights)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
#Distrbution plot

# %%
import seaborn as sns
import numpy as np
np.random.seed(0)
x= np.random.randn(100)
ax_1 = sns.distplot
print(ax_1)
# Out:
# <function distplot at 0x00000180896AE0C0>

# %%
ax_2 = sns.distplot(x, rug =True,hist=False)
# Out:
# C:\Users\eraas\AppData\Local\Temp\ipykernel_11240\1989273487.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_2 = sns.distplot(x, rug =True,hist=False)

# %%
ax_2 = sns.distplot(x, rug =False,hist=True)
# Out:
# C:\Users\eraas\AppData\Local\Temp\ipykernel_11240\2597735324.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_2 = sns.distplot(x, rug =False,hist=True)

# %%
from scipy.stats import norm
ax_3= sns.distplot(x,fit=norm)
# Out:
# C:\Users\eraas\AppData\Local\Temp\ipykernel_11240\410920775.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_3= sns.distplot(x,fit=norm)

# %%
ax_3= sns.distplot(x,fit=norm,kde=False)
# Out:
# C:\Users\eraas\AppData\Local\Temp\ipykernel_11240\3673996891.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_3= sns.distplot(x,fit=norm,kde=False)

# %%
ax_4 = sns.distplot(x,vertical = True)
# Out:
# C:\Users\eraas\AppData\Local\Temp\ipykernel_11240\4076346913.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_4 = sns.distplot(x,vertical = True)

# %%
sns.set_color_codes()
ax_5 = sns.distplot(x,color= 'r')
# Out:
# C:\Users\eraas\AppData\Local\Temp\ipykernel_11240\898077794.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_5 = sns.distplot(x,color= 'r')

# %%
sns.set(style = 'dark')
ax_6 = sns.distplot(x,color='g')
# Out:
# C:\Users\eraas\AppData\Local\Temp\ipykernel_11240\65873529.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_6 = sns.distplot(x,color='g')
