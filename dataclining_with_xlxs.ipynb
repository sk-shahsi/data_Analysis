# %%
import pandas as pd
path = "D:/Data_Analysis/dataclining.xlsx"
df=pd.read_excel(path)
print(df)
# Out:
#     s.no     A   B     C     D     E
# 0      1   2.0   1   5.0   3.0   4.0
# 1      2   4.0   3  10.0   6.0   8.0
# 2      3   6.0   5  15.0   9.0  12.0
# 3      4   8.0   7  20.0  12.0  16.0
# 4      5  10.0   9  25.0  15.0  20.0
# 5      6  12.0  11  30.0  18.0  24.0
# 6      7  14.0  13  35.0  21.0  28.0
# 7      8  16.0  15  40.0  24.0  32.0
# 8      9  18.0  17  45.0  27.0  36.0
# 9     10  20.0  19  50.0  30.0  40.0
# 10    11   NaN  21   NaN   NaN   NaN
# 11    12   NaN  22   NaN   NaN  45.0

# %%
df.head(5)
# Out:
#    s.no     A  B     C     D     E
# 0     1   2.0  1   5.0   3.0   4.0
# 1     2   4.0  3  10.0   6.0   8.0
# 2     3   6.0  5  15.0   9.0  12.0
# 3     4   8.0  7  20.0  12.0  16.0
# 4     5  10.0  9  25.0  15.0  20.0

# %%
headers = ["S.no","Even","Odd","Multiple 5","Multiple 3","Multiple 4"]
df.columns=headers
print(df)
# Out:
#     S.no  Even  Odd  Multiple 5  Multiple 3  Multiple 4
# 0      1   2.0    1         5.0         3.0         4.0
# 1      2   4.0    3        10.0         6.0         8.0
# 2      3   6.0    5        15.0         9.0        12.0
# 3      4   8.0    7        20.0        12.0        16.0
# 4      5  10.0    9        25.0        15.0        20.0
# 5      6  12.0   11        30.0        18.0        24.0
# 6      7  14.0   13        35.0        21.0        28.0
# 7      8  16.0   15        40.0        24.0        32.0
# 8      9  18.0   17        45.0        27.0        36.0
# 9     10  20.0   19        50.0        30.0        40.0
# 10    11   NaN   21         NaN         NaN         NaN
# 11    12   NaN   22         NaN         NaN        45.0

# %%
df["Odd"]=df["Odd"]+1

# %%
print(df)
# Out:
#     S.no  Even  Odd  Multiple 5  Multiple 3  Multiple 4
# 0      1   2.0    2         5.0         3.0         4.0
# 1      2   4.0    4        10.0         6.0         8.0
# 2      3   6.0    6        15.0         9.0        12.0
# 3      4   8.0    8        20.0        12.0        16.0
# 4      5  10.0   10        25.0        15.0        20.0
# 5      6  12.0   12        30.0        18.0        24.0
# 6      7  14.0   14        35.0        21.0        28.0
# 7      8  16.0   16        40.0        24.0        32.0
# 8      9  18.0   18        45.0        27.0        36.0
# 9     10  20.0   20        50.0        30.0        40.0
# 10    11   NaN   22         NaN         NaN         NaN
# 11    12   NaN   23         NaN         NaN        45.0

# %%
df["Odd"]=df["Odd"]-1
print(df)
# Out:
#     S.no  Even  Odd  Multiple 5  Multiple 3  Multiple 4
# 0      1   2.0    1         5.0         3.0         4.0
# 1      2   4.0    3        10.0         6.0         8.0
# 2      3   6.0    5        15.0         9.0        12.0
# 3      4   8.0    7        20.0        12.0        16.0
# 4      5  10.0    9        25.0        15.0        20.0
# 5      6  12.0   11        30.0        18.0        24.0
# 6      7  14.0   13        35.0        21.0        28.0
# 7      8  16.0   15        40.0        24.0        32.0
# 8      9  18.0   17        45.0        27.0        36.0
# 9     10  20.0   19        50.0        30.0        40.0
# 10    11   NaN   21         NaN         NaN         NaN
# 11    12   NaN   22         NaN         NaN        45.0

# %%
df.drop([10],axis=0)
print(df)
# Out:
#     S.no  Even  Odd  Multiple 5  Multiple 3  Multiple 4
# 0      1   2.0    1         5.0         3.0         4.0
# 1      2   4.0    3        10.0         6.0         8.0
# 2      3   6.0    5        15.0         9.0        12.0
# 3      4   8.0    7        20.0        12.0        16.0
# 4      5  10.0    9        25.0        15.0        20.0
# 5      6  12.0   11        30.0        18.0        24.0
# 6      7  14.0   13        35.0        21.0        28.0
# 7      8  16.0   15        40.0        24.0        32.0
# 8      9  18.0   17        45.0        27.0        36.0
# 9     10  20.0   19        50.0        30.0        40.0
# 10    11   NaN   21         NaN         NaN         NaN
# 11    12   NaN   22         NaN         NaN        45.0

# %%
df.dropna()
# Out:
#    S.no  Even  Odd  Multiple 5  Multiple 3  Multiple 4
# 0     1   2.0    1         5.0         3.0         4.0
# 1     2   4.0    3        10.0         6.0         8.0
# 2     3   6.0    5        15.0         9.0        12.0
# 3     4   8.0    7        20.0        12.0        16.0
# 4     5  10.0    9        25.0        15.0        20.0
# 5     6  12.0   11        30.0        18.0        24.0
# 6     7  14.0   13        35.0        21.0        28.0
# 7     8  16.0   15        40.0        24.0        32.0
# 8     9  18.0   17        45.0        27.0        36.0
# 9    10  20.0   19        50.0        30.0        40.0

# %%
import numpy as np
df["Even"].replace(np.nan,0,inplace=True)
print(df)
# Out:
#     S.no  Even  Odd  Multiple 5  Multiple 3  Multiple 4
# 0      1   2.0    1         5.0         3.0         4.0
# 1      2   4.0    3        10.0         6.0         8.0
# 2      3   6.0    5        15.0         9.0        12.0
# 3      4   8.0    7        20.0        12.0        16.0
# 4      5  10.0    9        25.0        15.0        20.0
# 5      6  12.0   11        30.0        18.0        24.0
# 6      7  14.0   13        35.0        21.0        28.0
# 7      8  16.0   15        40.0        24.0        32.0
# 8      9  18.0   17        45.0        27.0        36.0
# 9     10  20.0   19        50.0        30.0        40.0
# 10    11   0.0   21         NaN         NaN         NaN
# 11    12   0.0   22         NaN         NaN        45.0
# C:\Users\eraas\AppData\Local\Temp\ipykernel_4256\2751968644.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df["Multiple 4"]=df["Multiple 4"]/2

# %%
df.head(5)
# Out:
#    S.no  Even  Odd  Multiple 5  Multiple 3  Multiple 4
# 0     1   2.0    1         5.0         3.0         2.0
# 1     2   4.0    3        10.0         6.0         4.0
# 2     3   6.0    5        15.0         9.0         6.0
# 3     4   8.0    7        20.0        12.0         8.0
# 4     5  10.0    9        25.0        15.0        10.0

# %%
df.rename(columns={"Multiple 4":"Multiple 2"})
# Out:
#     S.no  Even  Odd  Multiple 5  Multiple 3  Multiple 2
# 0      1   2.0    1         5.0         3.0         2.0
# 1      2   4.0    3        10.0         6.0         4.0
# 2      3   6.0    5        15.0         9.0         6.0
# 3      4   8.0    7        20.0        12.0         8.0
# 4      5  10.0    9        25.0        15.0        10.0
# 5      6  12.0   11        30.0        18.0        12.0
# 6      7  14.0   13        35.0        21.0        14.0
# 7      8  16.0   15        40.0        24.0        16.0
# 8      9  18.0   17        45.0        27.0        18.0
# 9     10  20.0   19        50.0        30.0        20.0
# 10    11   0.0   21         NaN         NaN         NaN
# 11    12   0.0   22         NaN         NaN        22.5

# %%
df.dtypes
# Out:
# S.no            int64
# Even          float64
# Odd             int64
# Multiple 5    float64
# Multiple 3    float64
# Multiple 4    float64
# dtype: object

# %%
df["Multiple 4"]=df["Multiple 4"].astype("int")
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df["Multiple 4"]=df["Multiple 4"].astype("int")
#       2 df.head(5)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df.head(5)
# Out:
#    S.no  Even  Odd  Multiple 5  Multiple 3  Multiple 4
# 0     1   2.0    1         5.0         3.0         2.0
# 1     2   4.0    3        10.0         6.0         4.0
# 2     3   6.0    5        15.0         9.0         6.0
# 3     4   8.0    7        20.0        12.0         8.0
# 4     5  10.0    9        25.0        15.0        10.0
