# %%
import pandas as pd
path ="D:/Data_Analysis/data.csv"
df = pd.read_csv(path)
print(df)
# Out:
#        Unnamed: 0  year industry_code_ANZSIC  \
# 0               0  2011                    A
# 1               1  2011                    A
# 2               2  2011                    A
# 3               3  2011                    A
# 4               4  2011                    A
# ...           ...   ...                  ...
# 21667       21667  2024                  all
# 21668       21668  2024                  all
# 21669       21669  2024                  all
# 21670       21670  2024                  all
# 21671       21671  2024                  all
#
#                     industry_name_ANZSIC   rme_size_grp  \
# 0      Agriculture, Forestry and Fishing            a_0
# 1      Agriculture, Forestry and Fishing            a_0
# 2      Agriculture, Forestry and Fishing            a_0
# 3      Agriculture, Forestry and Fishing            a_0
# 4      Agriculture, Forestry and Fishing            a_0
# ...                                  ...            ...
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0           0  2011                    A  Agriculture, Forestry and Fishing
# 1           1  2011                    A  Agriculture, Forestry and Fishing
# 2           2  2011                    A  Agriculture, Forestry and Fishing
# 3           3  2011                    A  Agriculture, Forestry and Fishing
# 4           4  2011                    A  Agriculture, Forestry and Fishing
#
#   rme_size_grp                                         variable  value  \
# 0          a_0                                    Activity unit  46134
# 1          a_0                           Rolling mean employees      0
# 2          a_0                          Salaries and wages paid    279
# 3          a_0  Sales, government funding, grants and subsidies   8187
# 4          a_0                                     Total income   8866
#
#                 unit  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# ...

# %%
df.tail(5)
# Out:
#        Unnamed: 0  year industry_code_ANZSIC industry_name_ANZSIC  \
# 21667       21667  2024                  all       All Industries
# 21668       21668  2024                  all       All Industries
# 21669       21669  2024                  all       All Industries
# 21670       21670  2024                  all       All Industries
# 21671       21671  2024                  all       All Industries
#
#         rme_size_grp                                         variable  \
# 21667  j_Grand_Total                          Salaries and wages paid
# 21668  j_Grand_Total  Sales, government funding, grants and subsidies
# 21669  j_Grand_Total                                     Total assets
# 21670  j_Grand_Total                                Total expenditure
# 21671  j_Grand_Total                                     Total income
#
#          value               unit  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 21667   157616  DOLLARS(millions)         NaN         NaN         NaN
# ...

# %%
df.to_csv(path) #save The file

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# year                      int64
# industry_code_ANZSIC     object
# industry_name_ANZSIC     object
# rme_size_grp             object
# variable                 object
# value                    object
# unit                     object
# Unnamed: 7              float64
# Unnamed: 8              float64
# Unnamed: 9              float64
# Unnamed: 10              object
# Unnamed: 11              object
# Unnamed: 12              object
# Unnamed: 13              object
# Unnamed: 14              object
# Unnamed: 15              object
# dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0          year  Unnamed: 7  Unnamed: 8   Unnamed: 9
# count  21672.000000  21672.000000         0.0         0.0    41.000000
# mean   10835.500000   2017.500000         NaN         NaN  2022.268293
# std     6256.311853      4.031222         NaN         NaN     0.448575
# min        0.000000   2011.000000         NaN         NaN  2022.000000
# 25%     5417.750000   2014.000000         NaN         NaN  2022.000000
# 50%    10835.500000   2017.500000         NaN         NaN  2022.000000
# 75%    16253.250000   2021.000000         NaN         NaN  2023.000000
# max    21671.000000   2024.000000         NaN         NaN  2023.000000

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0          year industry_code_ANZSIC  \
# count   21672.000000  21672.000000                21672
# unique           NaN           NaN                   20
# top              NaN           NaN                    A
# freq             NaN           NaN                 1134
# mean    10835.500000   2017.500000                  NaN
# std      6256.311853      4.031222                  NaN
# min         0.000000   2011.000000                  NaN
# 25%      5417.750000   2014.000000                  NaN
# 50%     10835.500000   2017.500000                  NaN
# 75%     16253.250000   2021.000000                  NaN
# max     21671.000000   2024.000000                  NaN
#
#                      industry_name_ANZSIC rme_size_grp       variable  value  \
# count                               21672        21672          21672  21672
# unique                                 20           10              9   8808
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21672 entries, 0 to 21671
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            21672 non-null  int64
#  1   year                  21672 non-null  int64
#  2   industry_code_ANZSIC  21672 non-null  object
#  3   industry_name_ANZSIC  21672 non-null  object
#  4   rme_size_grp          21672 non-null  object
#  5   variable              21672 non-null  object
#  6   value                 21672 non-null  object
#  7   unit                  21672 non-null  object
#  8   Unnamed: 7            0 non-null      float64
#  9   Unnamed: 8            0 non-null      float64
#  10  Unnamed: 9            41 non-null     float64
#  11  Unnamed: 10           41 non-null     object
#  12  Unnamed: 11           41 non-null     object
#  13  Unnamed: 12           41 non-null     object
#  14  Unnamed: 13           41 non-null     object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'industry_code_ANZSIC', 'industry_name_ANZSIC',
#        'rme_size_grp', 'variable', 'value', 'unit', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')
